# %%
import cv2
import numpy as np
import pandas as pd 
import matplotlib.pyplot as pyplot
# %matplotlib inline 
import os
import random
import gc 
import glob

# %%
cd 'train_cat'
# Out:
# [Errno 2] No such file or directory: 'train_cat'
# /content

# %%
train = []
train_labels = []
files = glob.glob ("/content/drive/My Drive/train_cat/*.jpg") # your image path
for myFile in files:
    image = cv2.imread (myFile)
    train.append (image)
    train_labels.append([1., 0.])

# %%
train = np.array(train,dtype='object')

# %%
type(train)
# Out:
# numpy.ndarray

# %%
train[1].shape
# Out:
# (499, 489, 3)
